# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
RESULT_PATH = "./exp11/results.csv"

data = pd.read_csv(RESULT_PATH)

print(data.info())
data['Epoch'] = pd.Series([int(epoch.split("/")[0]) for epoch in data['Epoch']])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Epoch         150 non-null    object
#  1   gpu_mem       150 non-null    object
#  2   box           150 non-null    float64
#  3   obj           150 non-null    float64
#  4   cls           150 non-null    float64
#  5   total         150 non-null    float64
#  6   labels        150 non-null    int64
#  7   img_size      150 non-null    int64
#  8   P             150 non-null    float64
#  9   R             150 non-null    float64
#  10  mAP@.5        150 non-null    float64
#  11  mAP@0.5:0.95  150 non-null    float64
#  12  #1            150 non-null    float64
#  13  #2            150 non-null    float64
#  14  #3            150 non-null    float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 17.7+ KB
# None

# %%
fig, axs = plt.subplots(3, 3)
plt.rcParams['figure.figsize'] = (5, 5)
axs[0, 0].plot(data['Epoch'], data['box'])
axs[0, 0].set_title('Box')
axs[0, 1].plot(data['Epoch'], data['obj'])
axs[0, 1].set_title('Obj')
axs[0, 2].plot(data['Epoch'], data['cls'])
axs[0, 2].set_title('Cls')
axs[1, 0].plot(data['Epoch'], data['P'])
axs[1, 0].set_title('Precision')
axs[1, 1].plot(data['Epoch'], data['R'])
axs[1, 1].set_title('Recall')
axs[1, 2].plot(data['Epoch'], data['mAP@.5'])
axs[1, 2].set_title('mAP@.5')
axs[2, 0].plot(data['Epoch'], data['mAP@0.5:0.95'])
axs[2, 0].set_title('mAP@.5:0.95')
# Out:
# Text(0.5, 1.0, 'mAP@.5:0.95')
