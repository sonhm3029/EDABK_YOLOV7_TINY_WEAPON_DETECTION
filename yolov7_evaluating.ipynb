# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
RESULT_PATH = "./results.csv"

data = pd.read_csv(RESULT_PATH)

print(data.info())
data['Epoch'] = pd.Series([int(epoch.split("/")[0]) for epoch in data['Epoch']])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Epoch         90 non-null     object
#  1    gpu_mem      90 non-null     object
#  2   box           90 non-null     float64
#  3   obj           90 non-null     float64
#  4   cls           90 non-null     float64
#  5   total         90 non-null     float64
#  6   labels        90 non-null     int64
#  7   img_size      90 non-null     int64
#  8   P             90 non-null     float64
#  9   R             90 non-null     float64
#  10  mAP@.5        90 non-null     float64
#  11  mAP@0.5:0.95  90 non-null     float64
#  12   #1           90 non-null     float64
#  13   #2           90 non-null     float64
#  14  #3            90 non-null     float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 10.7+ KB
# None

# %%
fig, axs = plt.subplots(3, 3)
axs[0, 0].plot(data['Epoch'], data['box'])
axs[0, 0].set_title('Box')
axs[0, 1].plot(data['Epoch'], data['obj'])
axs[0, 1].set_title('Obj')
axs[0, 2].plot(data['Epoch'], data['cls'])
axs[0, 2].set_title('Cls')
axs[1, 0].plot(data['Epoch'], data['P'])
axs[1, 0].set_title('Precision')
axs[1, 1].plot(data['Epoch'], data['R'])
axs[1, 1].set_title('Recall')
axs[1, 2].plot(data['Epoch'], data['mAP@.5'])
axs[1, 2].set_title('mAP@.5')
axs[2, 0].plot(data['Epoch'], data['mAP@0.5:0.95'])
axs[2, 0].set_title('mAP@.5:0.95')
# Out:
# Text(0.5, 1.0, 'mAP@.5:0.95')

# %%
#Plotting data


plt.subplot(3,3,1)
plt.plot(data['Epoch'], data['obj'])
plt.subplot(3,3,2)
plt.plot(data['Epoch'], data['cls'])
# plt.subplot(3,3,3)
# plt.plot(data['Epoch'], data['P'])
# plt.subplot(3,3,4)
# plt.plot(data['Epoch'], data['R'])
# plt.subplot(3,3,5)
# plt.plot(data['Epoch'], data['mAP@.5'])
# plt.subplot(3,3,6)
# plt.plot(data['Epoch'], data['mAP@0.5:0.95'])
# plt.subplot(3,3,7)
# plt.plot(data['Epoch'], data['box'])

plt.show()
